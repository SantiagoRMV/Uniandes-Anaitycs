# %% [markdown]
# # Proyecto Optimización - Mejora Proceso Tulas
#
# ---
# ## Maestría en Inteligencia Analítica para la Toma de Decisiones
#
#
# * **Profesor**:
#     * *Andrés Medaglia*
# * **Grupo 8**:
#     * *Angelica Ruce*
#     * *David Moreno*
#     * *Nicolas Cruz*
#     * *Santiago Romero*

# %% [markdown]
# ## Formulación
# ---
#
# ### Parámetros
# >#### **Conjuntos**
# >* $I$: conjunto de Oficinas de Servicio
# >* $J$: conjunto de Centros Logisticos de Correspondencia - CLC
# >* $K$: conjunto de Cedes Admin Regionales - CAR
#
# >
# >#### **Parámetros**
# >* $a_i:$ Demandas mensuales de envio de tulas por oficina $i \in I$
# >* $r_k:$ Demandas mensuales de envio de tulas por CAR $k \in K$
# >* $p_k:$ Peso promedio de una tula enviada por la CAR k $k \in K$
# >* $w_{kj}:$ Costo de transporte de 1 kg de CAR k a CLC j | $k \in K$, $j \in J$
# >* $h_{kj}:$ Costo de transporte de 1 kg extra de CAR k a CLC j | $k \in K$, $j \in J$
# >* $c_{ij}:$ Costo de transporte de una tula enviada por la Oficina i al CLC j | $i \in I$, $j \in J$
#
#
# ### Variables de Decisión
# >* $x_{kj}:$ Cantidad de tulas a enviar del CAR k al CLC j $k\in K$, $j\in J$
# >* $m_{kj}:$ Cantidad de kg extra a enviar del CAR k al CLC j $k\in K$, $j\in J$
# >* $y_{ij}:$ Cantidad de tulas a enviar de la Oficinas i al CLC j $i\in I$, $j\in J$
#
# ### Restricciones
# > 1. Cada oficina $i\in I$ tiene una demanda de tulas a enviar que debe ser satisfecha
# >> $\sum_{j\in J} y_{ij} \geq d_i; \forall i\in I$
#
# > 2. Cada CAR $k\in K$ tiene una demanda de tulas a enviar que debe ser satisfecha
# >> $\sum_{j\in J} x_{kj} \geq r_k; \forall k\in K$
#
# > 3. El peso máximo de las tulas de enlace no debe superar los 30Kg, en caso de requerir incrementar el peso, se crea una restricción suave.
# >> $\sum_{k\in K}p_k x_{kj} + m_{kj} \geq 30$
#
# > **Naturaleza de Variables**
# >>$x_{kj}\in \mathbb{Z}^{+}$
#
# >>$y_{ij}\in \mathbb{Z}^{+}$
#
# >>$m_{kj}\geq 0 , \; \forall k\in K, j \in J$
#
# ### Función Objetivo
# > Maximizar el incremento en ventas dado por la inversión en canales de mercadeo.
# >> $\max{ \sum_{i\in I} a_ix_i}$

# %% [markdown]
# ## Importación de librerías
# ---

# %%
import pulp as lp
import pandas as pd

# %% [markdown]
# ## Creación de Parámetros
# ---

# %% [markdown]
# Importación de parámetros

# %%
archivo = "Soporte Proyecto Optimizacion.xlsx"
demandas_oficinas = pd.read_excel(archivo, sheet_name="Demanda Oficinas")
demandas_oficinas = demandas_oficinas.set_index(demandas_oficinas.columns[0])

demandas_car = pd.read_excel(archivo, sheet_name="Demandas CAR")
demandas_car = demandas_car.set_index(demandas_car.columns[0])

peso_tula = pd.read_excel(archivo, sheet_name="Peso Tula")
peso_tula = peso_tula.set_index(peso_tula.columns[0])

costos_kg = pd.read_excel(archivo, sheet_name="CAR-CLC_W")
costos_kg = costos_kg.set_index(costos_kg.columns[0])

costos_kg_extra = pd.read_excel(archivo, sheet_name="CAR-CLC_H")
costos_kg_extra = costos_kg_extra.set_index(costos_kg_extra.columns[0])

costos_transporte = pd.read_excel(archivo, sheet_name="Ofi-CLC")
costos_transporte = costos_transporte.set_index(costos_transporte.columns[0])

# %% [markdown]
# ### Conjuntos

# %%
# Conjunto Oficinas
oficinas = pd.read_excel(archivo, sheet_name="Oficinas")
lista_oficinas = oficinas['Oficinas'].tolist()
# Conjunto CLC
clc = pd.read_excel(archivo, sheet_name="CLC")
lista_clc = clc['CLC'].tolist()
# Conjunto CAR
car = pd.read_excel(archivo, sheet_name="CAR")
lista_car = car['CAR'].tolist()

# %%
# Parámetros indexados en (CAR, CLC)
costos_w = costos_kg.to_dict()
costos_w = {(ciudad_interior, ciudad_exterior): valor for ciudad_exterior, ciudades in costos_w.items() for ciudad_interior, valor in ciudades.items()}
costos_w_extra = costos_kg_extra.to_dict()
costos_w_extra = {(ciudad_interior, ciudad_exterior): valor for ciudad_exterior, ciudades in costos_w_extra.items() for ciudad_interior, valor in ciudades.items()}


#Parámetros indexados en (Oficina, CLC)
costo_transporte_oficinas = costos_transporte.to_dict()
costo_transporte_oficinas = {(ciudad_interior, ciudad_exterior): valor for ciudad_exterior, ciudades in costo_transporte_oficinas.items() for ciudad_interior, valor in ciudades.items()}


#Demanda Oficinas
demanda_oficina = demandas_oficinas['Demanda'].to_dict()
for clave, valor in demanda_oficina.items():
    demanda_oficina[clave] = int(valor)

#Demanda CAR
demanda_car = demandas_car['Demanda'].to_dict()
for clave, valor in demanda_car.items():
    demanda_car[clave] = int(valor)
    
#Peso tulas
peso_tula = peso_tula['Peso promedio kg'].to_dict()
for clave, valor in peso_tula.items():
    peso_tula[clave] = int(valor)
    
#Indices
CARxCLC = [(k, j) for k in lista_car for j in lista_clc]
Oficina_x_CLC = [(i, j) for i in lista_oficinas for j in lista_clc]

# %%
CARxCLC
# Out:
# [('ARAUCA', 'ARAUCA'),
#  ('ARAUCA', 'BARRANQUILA'),
#  ('ARAUCA', 'BOGOTA'),
#  ('ARAUCA', 'BUCARAMANGA'),
#  ('ARAUCA', 'CALI'),
#  ('ARAUCA', 'CUCUTA'),
#  ('ARAUCA', 'FLORENCIA'),
#  ('ARAUCA', 'IBAGUE'),
#  ('ARAUCA', 'MANIZALES'),
#  ('ARAUCA', 'MEDELLIN'),
#  ('ARAUCA', 'MOCOA'),
#  ('ARAUCA', 'MONTERIA'),
#  ('ARAUCA', 'NEIVA'),
#  ('ARAUCA', 'PASTO'),
#  ('ARAUCA', 'POPAYAN'),
#  ('ARAUCA', 'PROVIDENCIA'),
#  ('ARAUCA', 'SAN ANDRES'),
#  ('ARAUCA', 'SINCELEJO'),
#  ('ARAUCA', 'TUNJA'),
#  ('ARAUCA', 'VALLEDUPAR'),
#  ('ARAUCA', 'VILLAVICENCIO'),
#  ('ARAUCA', 'YOPAL'),
#  ('BARRANQUILA', 'ARAUCA'),
#  ('BARRANQUILA', 'BARRANQUILA'),
#  ('BARRANQUILA', 'BOGOTA'),
#  ('BARRANQUILA', 'BUCARAMANGA'),
#  ('BARRANQUILA', 'CALI'),
#  ('BARRANQUILA', 'CUCUTA'),
#  ('BARRANQUILA', 'FLORENCIA'),
#  ('BARRANQUILA', 'IBAGUE'),
#  ('BARRANQUILA', 'MANIZALES'),
#  ('BARRANQUILA', 'MEDELLIN'),
#  ('BARRANQUILA', 'MOCOA'),
#  ('BARRANQUILA', 'MONTERIA'),
#  ('BARRANQUILA', 'NEIVA'),
#  ('BARRANQUILA', 'PASTO'),
#  ('BARRANQUILA', 'POPAYAN'),
#  ('BARRANQUILA', 'PROVIDENCIA'),
#  ('BARRANQUILA', 'SAN ANDRES'),
#  ('BARRANQUILA', 'SINCELEJO'),
#  ('BARRANQUILA', 'TUNJA'),
#  ('BARRANQUILA', 'VALLEDUPAR'),
#  ('BARRANQUILA', 'VILLAVICENCIO'),
#  ('BARRANQUILA', 'YOPAL'),
#  ('BOGOTA', 'ARAUCA'),
#  ('BOGOTA', 'BARRANQUILA'),
#  ('BOGOTA', 'BOGOTA'),
#  ('BOGOTA', 'BUCARAMANGA'),
#  ('BOGOTA', 'CALI'),
#  ('BOGOTA', 'CUCUTA'),
#  ('BOGOTA', 'FLORENCIA'),
#  ('BOGOTA', 'IBAGUE'),
#  ('BOGOTA', 'MANIZALES'),
#  ('BOGOTA', 'MEDELLIN'),
#  ('BOGOTA', 'MOCOA'),
#  ('BOGOTA', 'MONTERIA'),
#  ('BOGOTA', 'NEIVA'),
#  ('BOGOTA', 'PASTO'),
#  ('BOGOTA', 'POPAYAN'),
#  ('BOGOTA', 'PROVIDENCIA'),
#  ('BOGOTA', 'SAN ANDRES'),
#  ('BOGOTA', 'SINCELEJO'),
#  ('BOGOTA', 'TUNJA'),
#  ('BOGOTA', 'VALLEDUPAR'),
#  ('BOGOTA', 'VILLAVICENCIO'),
#  ('BOGOTA', 'YOPAL'),
#  ('BUCARAMANGA', 'ARAUCA'),
#  ('BUCARAMANGA', 'BARRANQUILA'),
#  ('BUCARAMANGA', 'BOGOTA'),
#  ('BUCARAMANGA', 'BUCARAMANGA'),
#  ('BUCARAMANGA', 'CALI'),
#  ('BUCARAMANGA', 'CUCUTA'),
#  ('BUCARAMANGA', 'FLORENCIA'),
#  ('BUCARAMANGA', 'IBAGUE'),
#  ('BUCARAMANGA', 'MANIZALES'),
#  ('BUCARAMANGA', 'MEDELLIN'),
#  ('BUCARAMANGA', 'MOCOA'),
#  ('BUCARAMANGA', 'MONTERIA'),
#  ('BUCARAMANGA', 'NEIVA'),
#  ('BUCARAMANGA', 'PASTO'),
#  ('BUCARAMANGA', 'POPAYAN'),
#  ('BUCARAMANGA', 'PROVIDENCIA'),
#  ('BUCARAMANGA', 'SAN ANDRES'),
#  ('BUCARAMANGA', 'SINCELEJO'),
#  ('BUCARAMANGA', 'TUNJA'),
#  ('BUCARAMANGA', 'VALLEDUPAR'),
#  ('BUCARAMANGA', 'VILLAVICENCIO'),
#  ('BUCARAMANGA', 'YOPAL'),
#  ('CALI', 'ARAUCA'),
#  ('CALI', 'BARRANQUILA'),
#  ('CALI', 'BOGOTA'),
#  ('CALI', 'BUCARAMANGA'),
#  ('CALI', 'CALI'),
#  ('CALI', 'CUCUTA'),
#  ('CALI', 'FLORENCIA'),
#  ('CALI', 'IBAGUE'),
#  ('CALI', 'MANIZALES'),
#  ('CALI', 'MEDELLIN'),
#  ('CALI', 'MOCOA'),
#  ('CALI', 'MONTERIA'),
#  ('CALI', 'NEIVA'),
#  ('CALI', 'PASTO'),
#  ('CALI', 'POPAYAN'),
#  ('CALI', 'PROVIDENCIA'),
#  ('CALI', 'SAN ANDRES'),
#  ('CALI', 'SINCELEJO'),
#  ('CALI', 'TUNJA'),
#  ('CALI', 'VALLEDUPAR'),
#  ('CALI', 'VILLAVICENCIO'),
#  ('CALI', 'YOPAL'),
#  ('CUCUTA', 'ARAUCA'),
#  ('CUCUTA', 'BARRANQUILA'),
#  ('CUCUTA', 'BOGOTA'),
#  ('CUCUTA', 'BUCARAMANGA'),
#  ('CUCUTA', 'CALI'),
#  ('CUCUTA', 'CUCUTA'),
#  ('CUCUTA', 'FLORENCIA'),
#  ('CUCUTA', 'IBAGUE'),
#  ('CUCUTA', 'MANIZALES'),
#  ('CUCUTA', 'MEDELLIN'),
#  ('CUCUTA', 'MOCOA'),
#  ('CUCUTA', 'MONTERIA'),
#  ('CUCUTA', 'NEIVA'),
#  ('CUCUTA', 'PASTO'),
#  ('CUCUTA', 'POPAYAN'),
#  ('CUCUTA', 'PROVIDENCIA'),
#  ('CUCUTA', 'SAN ANDRES'),
#  ('CUCUTA', 'SINCELEJO'),
#  ('CUCUTA', 'TUNJA'),
#  ('CUCUTA', 'VALLEDUPAR'),
#  ('CUCUTA', 'VILLAVICENCIO'),
#  ('CUCUTA', 'YOPAL'),
#  ('FLORENCIA', 'ARAUCA'),
#  ('FLORENCIA', 'BARRANQUILA'),
#  ('FLORENCIA', 'BOGOTA'),
#  ('FLORENCIA', 'BUCARAMANGA'),
#  ('FLORENCIA', 'CALI'),
#  ('FLORENCIA', 'CUCUTA'),
#  ('FLORENCIA', 'FLORENCIA'),
#  ('FLORENCIA', 'IBAGUE'),
#  ('FLORENCIA', 'MANIZALES'),
#  ('FLORENCIA', 'MEDELLIN'),
#  ('FLORENCIA', 'MOCOA'),
#  ('FLORENCIA', 'MONTERIA'),
#  ('FLORENCIA', 'NEIVA'),
#  ('FLORENCIA', 'PASTO'),
#  ('FLORENCIA', 'POPAYAN'),
#  ('FLORENCIA', 'PROVIDENCIA'),
#  ('FLORENCIA', 'SAN ANDRES'),
#  ('FLORENCIA', 'SINCELEJO'),
#  ('FLORENCIA', 'TUNJA'),
#  ('FLORENCIA', 'VALLEDUPAR'),
#  ('FLORENCIA', 'VILLAVICENCIO'),
#  ('FLORENCIA', 'YOPAL'),
#  ('IBAGUE', 'ARAUCA'),
#  ('IBAGUE', 'BARRANQUILA'),
#  ('IBAGUE', 'BOGOTA'),
#  ('IBAGUE', 'BUCARAMANGA'),
#  ('IBAGUE', 'CALI'),
#  ('IBAGUE', 'CUCUTA'),
#  ('IBAGUE', 'FLORENCIA'),
#  ('IBAGUE', 'IBAGUE'),
#  ('IBAGUE', 'MANIZALES'),
#  ('IBAGUE', 'MEDELLIN'),
#  ('IBAGUE', 'MOCOA'),
#  ('IBAGUE', 'MONTERIA'),
#  ('IBAGUE', 'NEIVA'),
#  ('IBAGUE', 'PASTO'),
#  ('IBAGUE', 'POPAYAN'),
#  ('IBAGUE', 'PROVIDENCIA'),
#  ('IBAGUE', 'SAN ANDRES'),
#  ('IBAGUE', 'SINCELEJO'),
#  ('IBAGUE', 'TUNJA'),
#  ('IBAGUE', 'VALLEDUPAR'),
#  ('IBAGUE', 'VILLAVICENCIO'),
#  ('IBAGUE', 'YOPAL'),
#  ('MANIZALES', 'ARAUCA'),
#  ('MANIZALES', 'BARRANQUILA'),
#  ('MANIZALES', 'BOGOTA'),
#  ('MANIZALES', 'BUCARAMANGA'),
#  ('MANIZALES', 'CALI'),
#  ('MANIZALES', 'CUCUTA'),
#  ('MANIZALES', 'FLORENCIA'),
#  ('MANIZALES', 'IBAGUE'),
#  ('MANIZALES', 'MANIZALES'),
#  ('MANIZALES', 'MEDELLIN'),
#  ('MANIZALES', 'MOCOA'),
#  ('MANIZALES', 'MONTERIA'),
#  ('MANIZALES', 'NEIVA'),
#  ('MANIZALES', 'PASTO'),
#  ('MANIZALES', 'POPAYAN'),
#  ('MANIZALES', 'PROVIDENCIA'),
#  ('MANIZALES', 'SAN ANDRES'),
#  ('MANIZALES', 'SINCELEJO'),
#  ('MANIZALES', 'TUNJA'),
#  ('MANIZALES', 'VALLEDUPAR'),
#  ('MANIZALES', 'VILLAVICENCIO'),
#  ('MANIZALES', 'YOPAL'),
#  ('MEDELLIN', 'ARAUCA'),
#  ('MEDELLIN', 'BARRANQUILA'),
#  ('MEDELLIN', 'BOGOTA'),
#  ('MEDELLIN', 'BUCARAMANGA'),
#  ('MEDELLIN', 'CALI'),
#  ('MEDELLIN', 'CUCUTA'),
#  ('MEDELLIN', 'FLORENCIA'),
#  ('MEDELLIN', 'IBAGUE'),
#  ('MEDELLIN', 'MANIZALES'),
#  ('MEDELLIN', 'MEDELLIN'),
#  ('MEDELLIN', 'MOCOA'),
#  ('MEDELLIN', 'MONTERIA'),
#  ('MEDELLIN', 'NEIVA'),
#  ('MEDELLIN', 'PASTO'),
#  ('MEDELLIN', 'POPAYAN'),
#  ('MEDELLIN', 'PROVIDENCIA'),
#  ('MEDELLIN', 'SAN ANDRES'),
#  ('MEDELLIN', 'SINCELEJO'),
#  ('MEDELLIN', 'TUNJA'),
#  ('MEDELLIN', 'VALLEDUPAR'),
#  ('MEDELLIN', 'VILLAVICENCIO'),
#  ('MEDELLIN', 'YOPAL'),
#  ('MOCOA', 'ARAUCA'),
#  ('MOCOA', 'BARRANQUILA'),
#  ('MOCOA', 'BOGOTA'),
#  ('MOCOA', 'BUCARAMANGA'),
#  ('MOCOA', 'CALI'),
#  ('MOCOA', 'CUCUTA'),
#  ('MOCOA', 'FLORENCIA'),
#  ('MOCOA', 'IBAGUE'),
#  ('MOCOA', 'MANIZALES'),
#  ('MOCOA', 'MEDELLIN'),
#  ('MOCOA', 'MOCOA'),
#  ('MOCOA', 'MONTERIA'),
#  ('MOCOA', 'NEIVA'),
#  ('MOCOA', 'PASTO'),
#  ('MOCOA', 'POPAYAN'),
#  ('MOCOA', 'PROVIDENCIA'),
#  ('MOCOA', 'SAN ANDRES'),
#  ('MOCOA', 'SINCELEJO'),
#  ('MOCOA', 'TUNJA'),
#  ('MOCOA', 'VALLEDUPAR'),
#  ('MOCOA', 'VILLAVICENCIO'),
#  ('MOCOA', 'YOPAL'),
#  ('MONTERIA', 'ARAUCA'),
#  ('MONTERIA', 'BARRANQUILA'),
#  ('MONTERIA', 'BOGOTA'),
#  ('MONTERIA', 'BUCARAMANGA'),
#  ('MONTERIA', 'CALI'),
#  ('MONTERIA', 'CUCUTA'),
#  ('MONTERIA', 'FLORENCIA'),
#  ('MONTERIA', 'IBAGUE'),
#  ('MONTERIA', 'MANIZALES'),
#  ('MONTERIA', 'MEDELLIN'),
#  ('MONTERIA', 'MOCOA'),
#  ('MONTERIA', 'MONTERIA'),
#  ('MONTERIA', 'NEIVA'),
#  ('MONTERIA', 'PASTO'),
#  ('MONTERIA', 'POPAYAN'),
#  ('MONTERIA', 'PROVIDENCIA'),
#  ('MONTERIA', 'SAN ANDRES'),
#  ('MONTERIA', 'SINCELEJO'),
#  ('MONTERIA', 'TUNJA'),
#  ('MONTERIA', 'VALLEDUPAR'),
#  ('MONTERIA', 'VILLAVICENCIO'),
#  ('MONTERIA', 'YOPAL'),
#  ('NEIVA', 'ARAUCA'),
#  ('NEIVA', 'BARRANQUILA'),
#  ('NEIVA', 'BOGOTA'),
#  ('NEIVA', 'BUCARAMANGA'),
#  ('NEIVA', 'CALI'),
#  ('NEIVA', 'CUCUTA'),
#  ('NEIVA', 'FLORENCIA'),
#  ('NEIVA', 'IBAGUE'),
#  ('NEIVA', 'MANIZALES'),
#  ('NEIVA', 'MEDELLIN'),
#  ('NEIVA', 'MOCOA'),
#  ('NEIVA', 'MONTERIA'),
#  ('NEIVA', 'NEIVA'),
#  ('NEIVA', 'PASTO'),
#  ('NEIVA', 'POPAYAN'),
#  ('NEIVA', 'PROVIDENCIA'),
#  ('NEIVA', 'SAN ANDRES'),
#  ('NEIVA', 'SINCELEJO'),
#  ('NEIVA', 'TUNJA'),
#  ('NEIVA', 'VALLEDUPAR'),
#  ('NEIVA', 'VILLAVICENCIO'),
#  ('NEIVA', 'YOPAL'),
#  ('PASTO', 'ARAUCA'),
#  ('PASTO', 'BARRANQUILA'),
#  ('PASTO', 'BOGOTA'),
#  ('PASTO', 'BUCARAMANGA'),
#  ('PASTO', 'CALI'),
#  ('PASTO', 'CUCUTA'),
#  ('PASTO', 'FLORENCIA'),
#  ('PASTO', 'IBAGUE'),
#  ('PASTO', 'MANIZALES'),
#  ('PASTO', 'MEDELLIN'),
#  ('PASTO', 'MOCOA'),
#  ('PASTO', 'MONTERIA'),
#  ('PASTO', 'NEIVA'),
#  ('PASTO', 'PASTO'),
#  ('PASTO', 'POPAYAN'),
#  ('PASTO', 'PROVIDENCIA'),
#  ('PASTO', 'SAN ANDRES'),
#  ('PASTO', 'SINCELEJO'),
#  ('PASTO', 'TUNJA'),
#  ('PASTO', 'VALLEDUPAR'),
#  ('PASTO', 'VILLAVICENCIO'),
#  ('PASTO', 'YOPAL'),
#  ('POPAYAN', 'ARAUCA'),
#  ('POPAYAN', 'BARRANQUILA'),
#  ('POPAYAN', 'BOGOTA'),
#  ('POPAYAN', 'BUCARAMANGA'),
#  ('POPAYAN', 'CALI'),
#  ('POPAYAN', 'CUCUTA'),
#  ('POPAYAN', 'FLORENCIA'),
#  ('POPAYAN', 'IBAGUE'),
#  ('POPAYAN', 'MANIZALES'),
#  ('POPAYAN', 'MEDELLIN'),
#  ('POPAYAN', 'MOCOA'),
#  ('POPAYAN', 'MONTERIA'),
#  ('POPAYAN', 'NEIVA'),
#  ('POPAYAN', 'PASTO'),
#  ('POPAYAN', 'POPAYAN'),
#  ('POPAYAN', 'PROVIDENCIA'),
#  ('POPAYAN', 'SAN ANDRES'),
#  ('POPAYAN', 'SINCELEJO'),
#  ('POPAYAN', 'TUNJA'),
#  ('POPAYAN', 'VALLEDUPAR'),
#  ('POPAYAN', 'VILLAVICENCIO'),
#  ('POPAYAN', 'YOPAL'),
#  ('PROVIDENCIA', 'ARAUCA'),
#  ('PROVIDENCIA', 'BARRANQUILA'),
#  ('PROVIDENCIA', 'BOGOTA'),
#  ('PROVIDENCIA', 'BUCARAMANGA'),
#  ('PROVIDENCIA', 'CALI'),
#  ('PROVIDENCIA', 'CUCUTA'),
#  ('PROVIDENCIA', 'FLORENCIA'),
#  ('PROVIDENCIA', 'IBAGUE'),
#  ('PROVIDENCIA', 'MANIZALES'),
#  ('PROVIDENCIA', 'MEDELLIN'),
#  ('PROVIDENCIA', 'MOCOA'),
#  ('PROVIDENCIA', 'MONTERIA'),
#  ('PROVIDENCIA', 'NEIVA'),
#  ('PROVIDENCIA', 'PASTO'),
#  ('PROVIDENCIA', 'POPAYAN'),
#  ('PROVIDENCIA', 'PROVIDENCIA'),
#  ('PROVIDENCIA', 'SAN ANDRES'),
#  ('PROVIDENCIA', 'SINCELEJO'),
#  ('PROVIDENCIA', 'TUNJA'),
#  ('PROVIDENCIA', 'VALLEDUPAR'),
#  ('PROVIDENCIA', 'VILLAVICENCIO'),
#  ('PROVIDENCIA', 'YOPAL'),
#  ('SAN ANDRES', 'ARAUCA'),
#  ('SAN ANDRES', 'BARRANQUILA'),
#  ('SAN ANDRES', 'BOGOTA'),
#  ('SAN ANDRES', 'BUCARAMANGA'),
#  ('SAN ANDRES', 'CALI'),
#  ('SAN ANDRES', 'CUCUTA'),
#  ('SAN ANDRES', 'FLORENCIA'),
#  ('SAN ANDRES', 'IBAGUE'),
#  ('SAN ANDRES', 'MANIZALES'),
#  ('SAN ANDRES', 'MEDELLIN'),
#  ('SAN ANDRES', 'MOCOA'),
#  ('SAN ANDRES', 'MONTERIA'),
#  ('SAN ANDRES', 'NEIVA'),
#  ('SAN ANDRES', 'PASTO'),
#  ('SAN ANDRES', 'POPAYAN'),
#  ('SAN ANDRES', 'PROVIDENCIA'),
#  ('SAN ANDRES', 'SAN ANDRES'),
#  ('SAN ANDRES', 'SINCELEJO'),
#  ('SAN ANDRES', 'TUNJA'),
#  ('SAN ANDRES', 'VALLEDUPAR'),
#  ('SAN ANDRES', 'VILLAVICENCIO'),
#  ('SAN ANDRES', 'YOPAL'),
#  ('SINCELEJO', 'ARAUCA'),
#  ('SINCELEJO', 'BARRANQUILA'),
#  ('SINCELEJO', 'BOGOTA'),
#  ('SINCELEJO', 'BUCARAMANGA'),
#  ('SINCELEJO', 'CALI'),
#  ('SINCELEJO', 'CUCUTA'),
#  ('SINCELEJO', 'FLORENCIA'),
#  ('SINCELEJO', 'IBAGUE'),
#  ('SINCELEJO', 'MANIZALES'),
#  ('SINCELEJO', 'MEDELLIN'),
#  ('SINCELEJO', 'MOCOA'),
#  ('SINCELEJO', 'MONTERIA'),
#  ('SINCELEJO', 'NEIVA'),
#  ('SINCELEJO', 'PASTO'),
#  ('SINCELEJO', 'POPAYAN'),
#  ('SINCELEJO', 'PROVIDENCIA'),
#  ('SINCELEJO', 'SAN ANDRES'),
#  ('SINCELEJO', 'SINCELEJO'),
#  ('SINCELEJO', 'TUNJA'),
#  ('SINCELEJO', 'VALLEDUPAR'),
#  ('SINCELEJO', 'VILLAVICENCIO'),
#  ('SINCELEJO', 'YOPAL'),
#  ('TUNJA', 'ARAUCA'),
#  ('TUNJA', 'BARRANQUILA'),
#  ('TUNJA', 'BOGOTA'),
#  ('TUNJA', 'BUCARAMANGA'),
#  ('TUNJA', 'CALI'),
#  ('TUNJA', 'CUCUTA'),
#  ('TUNJA', 'FLORENCIA'),
#  ('TUNJA', 'IBAGUE'),
#  ('TUNJA', 'MANIZALES'),
#  ('TUNJA', 'MEDELLIN'),
#  ('TUNJA', 'MOCOA'),
#  ('TUNJA', 'MONTERIA'),
#  ('TUNJA', 'NEIVA'),
#  ('TUNJA', 'PASTO'),
#  ('TUNJA', 'POPAYAN'),
#  ('TUNJA', 'PROVIDENCIA'),
#  ('TUNJA', 'SAN ANDRES'),
#  ('TUNJA', 'SINCELEJO'),
#  ('TUNJA', 'TUNJA'),
#  ('TUNJA', 'VALLEDUPAR'),
#  ('TUNJA', 'VILLAVICENCIO'),
#  ('TUNJA', 'YOPAL'),
#  ('VALLEDUPAR', 'ARAUCA'),
#  ('VALLEDUPAR', 'BARRANQUILA'),
#  ('VALLEDUPAR', 'BOGOTA'),
#  ('VALLEDUPAR', 'BUCARAMANGA'),
#  ('VALLEDUPAR', 'CALI'),
#  ('VALLEDUPAR', 'CUCUTA'),
#  ('VALLEDUPAR', 'FLORENCIA'),
#  ('VALLEDUPAR', 'IBAGUE'),
#  ('VALLEDUPAR', 'MANIZALES'),
#  ('VALLEDUPAR', 'MEDELLIN'),
#  ('VALLEDUPAR', 'MOCOA'),
#  ('VALLEDUPAR', 'MONTERIA'),
#  ('VALLEDUPAR', 'NEIVA'),
#  ('VALLEDUPAR', 'PASTO'),
#  ('VALLEDUPAR', 'POPAYAN'),
#  ('VALLEDUPAR', 'PROVIDENCIA'),
#  ('VALLEDUPAR', 'SAN ANDRES'),
#  ('VALLEDUPAR', 'SINCELEJO'),
#  ('VALLEDUPAR', 'TUNJA'),
#  ('VALLEDUPAR', 'VALLEDUPAR'),
#  ('VALLEDUPAR', 'VILLAVICENCIO'),
#  ('VALLEDUPAR', 'YOPAL'),
#  ('VILLAVICENCIO', 'ARAUCA'),
#  ('VILLAVICENCIO', 'BARRANQUILA'),
#  ('VILLAVICENCIO', 'BOGOTA'),
#  ('VILLAVICENCIO', 'BUCARAMANGA'),
#  ('VILLAVICENCIO', 'CALI'),
#  ('VILLAVICENCIO', 'CUCUTA'),
#  ('VILLAVICENCIO', 'FLORENCIA'),
#  ('VILLAVICENCIO', 'IBAGUE'),
#  ('VILLAVICENCIO', 'MANIZALES'),
#  ('VILLAVICENCIO', 'MEDELLIN'),
#  ('VILLAVICENCIO', 'MOCOA'),
#  ('VILLAVICENCIO', 'MONTERIA'),
#  ('VILLAVICENCIO', 'NEIVA'),
#  ('VILLAVICENCIO', 'PASTO'),
#  ('VILLAVICENCIO', 'POPAYAN'),
#  ('VILLAVICENCIO', 'PROVIDENCIA'),
#  ('VILLAVICENCIO', 'SAN ANDRES'),
#  ('VILLAVICENCIO', 'SINCELEJO'),
#  ('VILLAVICENCIO', 'TUNJA'),
#  ('VILLAVICENCIO', 'VALLEDUPAR'),
#  ('VILLAVICENCIO', 'VILLAVICENCIO'),
#  ('VILLAVICENCIO', 'YOPAL'),
#  ('YOPAL', 'ARAUCA'),
#  ('YOPAL', 'BARRANQUILA'),
#  ('YOPAL', 'BOGOTA'),
#  ('YOPAL', 'BUCARAMANGA'),
#  ('YOPAL', 'CALI'),
#  ('YOPAL', 'CUCUTA'),
#  ('YOPAL', 'FLORENCIA'),
#  ('YOPAL', 'IBAGUE'),
#  ('YOPAL', 'MANIZALES'),
#  ('YOPAL', 'MEDELLIN'),
#  ('YOPAL', 'MOCOA'),
#  ('YOPAL', 'MONTERIA'),
#  ('YOPAL', 'NEIVA'),
#  ('YOPAL', 'PASTO'),
#  ('YOPAL', 'POPAYAN'),
#  ('YOPAL', 'PROVIDENCIA'),
#  ('YOPAL', 'SAN ANDRES'),
#  ('YOPAL', 'SINCELEJO'),
#  ('YOPAL', 'TUNJA'),
#  ('YOPAL', 'VALLEDUPAR'),
#  ('YOPAL', 'VILLAVICENCIO'),
#  ('YOPAL', 'YOPAL')]

# %%
costos_w
# Out:
# {('ARAUCA', 'ARAUCA'): 10613,
#  ('BARRANQUILA', 'ARAUCA'): 7217,
#  ('BOGOTA', 'ARAUCA'): 6952,
#  ('BUCARAMANGA', 'ARAUCA'): 7308,
#  ('CALI', 'ARAUCA'): 6865,
#  ('CUCUTA', 'ARAUCA'): 5743,
#  ('FLORENCIA', 'ARAUCA'): 11200,
#  ('IBAGUE', 'ARAUCA'): 9492,
#  ('MANIZALES', 'ARAUCA'): 9761,
#  ('MEDELLIN', 'ARAUCA'): 8991,
#  ('MOCOA', 'ARAUCA'): 7454,
#  ('MONTERIA', 'ARAUCA'): 7220,
#  ('NEIVA', 'ARAUCA'): 9497,
#  ('PASTO', 'ARAUCA'): 6168,
#  ('POPAYAN', 'ARAUCA'): 6882,
#  ('PROVIDENCIA', 'ARAUCA'): 9661,
#  ('SAN ANDRES', 'ARAUCA'): 10838,
#  ('SINCELEJO', 'ARAUCA'): 11637,
#  ('TUNJA', 'ARAUCA'): 12166,
#  ('VALLEDUPAR', 'ARAUCA'): 10921,
#  ('VILLAVICENCIO', 'ARAUCA'): 6960,
#  ('YOPAL', 'ARAUCA'): 9564,
#  ('ARAUCA', 'BARRANQUILA'): 6731,
#  ('BARRANQUILA', 'BARRANQUILA'): 12106,
#  ('BOGOTA', 'BARRANQUILA'): 10550,
#  ('BUCARAMANGA', 'BARRANQUILA'): 6730,
#  ('CALI', 'BARRANQUILA'): 6866,
#  ('CUCUTA', 'BARRANQUILA'): 11173,
#  ('FLORENCIA', 'BARRANQUILA'): 8407,
#  ('IBAGUE', 'BARRANQUILA'): 9394,
#  ('MANIZALES', 'BARRANQUILA'): 6462,
#  ('MEDELLIN', 'BARRANQUILA'): 11366,
#  ('MOCOA', 'BARRANQUILA'): 9592,
#  ('MONTERIA', 'BARRANQUILA'): 10823,
#  ('NEIVA', 'BARRANQUILA'): 11817,
#  ('PASTO', 'BARRANQUILA'): 9196,
#  ('POPAYAN', 'BARRANQUILA'): 11400,
#  ('PROVIDENCIA', 'BARRANQUILA'): 11498,
#  ('SAN ANDRES', 'BARRANQUILA'): 7343,
#  ('SINCELEJO', 'BARRANQUILA'): 8291,
#  ('TUNJA', 'BARRANQUILA'): 11840,
#  ('VALLEDUPAR', 'BARRANQUILA'): 12035,
#  ('VILLAVICENCIO', 'BARRANQUILA'): 6711,
#  ('YOPAL', 'BARRANQUILA'): 7643,
#  ('ARAUCA', 'BOGOTA'): 5785,
#  ('BARRANQUILA', 'BOGOTA'): 8300,
#  ('BOGOTA', 'BOGOTA'): 11359,
#  ('BUCARAMANGA', 'BOGOTA'): 9934,
#  ('CALI', 'BOGOTA'): 10657,
#  ('CUCUTA', 'BOGOTA'): 5885,
#  ('FLORENCIA', 'BOGOTA'): 11871,
#  ('IBAGUE', 'BOGOTA'): 9831,
#  ('MANIZALES', 'BOGOTA'): 9428,
#  ('MEDELLIN', 'BOGOTA'): 7670,
#  ('MOCOA', 'BOGOTA'): 6897,
#  ('MONTERIA', 'BOGOTA'): 8900,
#  ('NEIVA', 'BOGOTA'): 7575,
#  ('PASTO', 'BOGOTA'): 7749,
#  ('POPAYAN', 'BOGOTA'): 9216,
#  ('PROVIDENCIA', 'BOGOTA'): 6984,
#  ('SAN ANDRES', 'BOGOTA'): 11198,
#  ('SINCELEJO', 'BOGOTA'): 6989,
#  ('TUNJA', 'BOGOTA'): 6511,
#  ('VALLEDUPAR', 'BOGOTA'): 10328,
#  ('VILLAVICENCIO', 'BOGOTA'): 7914,
#  ('YOPAL', 'BOGOTA'): 7717,
#  ('ARAUCA', 'BUCARAMANGA'): 7681,
#  ('BARRANQUILA', 'BUCARAMANGA'): 10514,
#  ('BOGOTA', 'BUCARAMANGA'): 5768,
#  ('BUCARAMANGA', 'BUCARAMANGA'): 6868,
#  ('CALI', 'BUCARAMANGA'): 10801,
#  ('CUCUTA', 'BUCARAMANGA'): 11369,
#  ('FLORENCIA', 'BUCARAMANGA'): 10677,
#  ('IBAGUE', 'BUCARAMANGA'): 10772,
#  ('MANIZALES', 'BUCARAMANGA'): 6455,
#  ('MEDELLIN', 'BUCARAMANGA'): 8996,
#  ('MOCOA', 'BUCARAMANGA'): 8389,
#  ('MONTERIA', 'BUCARAMANGA'): 11273,
#  ('NEIVA', 'BUCARAMANGA'): 6634,
#  ('PASTO', 'BUCARAMANGA'): 8418,
#  ('POPAYAN', 'BUCARAMANGA'): 11396,
#  ('PROVIDENCIA', 'BUCARAMANGA'): 11496,
#  ('SAN ANDRES', 'BUCARAMANGA'): 8068,
#  ('SINCELEJO', 'BUCARAMANGA'): 8254,
#  ('TUNJA', 'BUCARAMANGA'): 6869,
#  ('VALLEDUPAR', 'BUCARAMANGA'): 11389,
#  ('VILLAVICENCIO', 'BUCARAMANGA'): 7621,
#  ('YOPAL', 'BUCARAMANGA'): 11182,
#  ('ARAUCA', 'CALI'): 6014,
#  ('BARRANQUILA', 'CALI'): 6381,
#  ('BOGOTA', 'CALI'): 10605,
#  ('BUCARAMANGA', 'CALI'): 10109,
#  ('CALI', 'CALI'): 11534,
#  ('CUCUTA', 'CALI'): 6665,
#  ('FLORENCIA', 'CALI'): 8058,
#  ('IBAGUE', 'CALI'): 11781,
#  ('MANIZALES', 'CALI'): 9264,
#  ('MEDELLIN', 'CALI'): 7678,
#  ('MOCOA', 'CALI'): 11945,
#  ('MONTERIA', 'CALI'): 12037,
#  ('NEIVA', 'CALI'): 6639,
#  ('PASTO', 'CALI'): 10322,
#  ('POPAYAN', 'CALI'): 9950,
#  ('PROVIDENCIA', 'CALI'): 8269,
#  ('SAN ANDRES', 'CALI'): 5933,
#  ('SINCELEJO', 'CALI'): 9180,
#  ('TUNJA', 'CALI'): 9325,
#  ('VALLEDUPAR', 'CALI'): 9373,
#  ('VILLAVICENCIO', 'CALI'): 9913,
#  ('YOPAL', 'CALI'): 11943,
#  ('ARAUCA', 'CUCUTA'): 6025,
#  ('BARRANQUILA', 'CUCUTA'): 8271,
#  ('BOGOTA', 'CUCUTA'): 6258,
#  ('BUCARAMANGA', 'CUCUTA'): 11698,
#  ('CALI', 'CUCUTA'): 7109,
#  ('CUCUTA', 'CUCUTA'): 8066,
#  ('FLORENCIA', 'CUCUTA'): 11683,
#  ('IBAGUE', 'CUCUTA'): 7479,
#  ('MANIZALES', 'CUCUTA'): 8856,
#  ('MEDELLIN', 'CUCUTA'): 10183,
#  ('MOCOA', 'CUCUTA'): 8883,
#  ('MONTERIA', 'CUCUTA'): 9596,
#  ('NEIVA', 'CUCUTA'): 6775,
#  ('PASTO', 'CUCUTA'): 8393,
#  ('POPAYAN', 'CUCUTA'): 8792,
#  ('PROVIDENCIA', 'CUCUTA'): 11455,
#  ('SAN ANDRES', 'CUCUTA'): 10190,
#  ('SINCELEJO', 'CUCUTA'): 8621,
#  ('TUNJA', 'CUCUTA'): 9972,
#  ('VALLEDUPAR', 'CUCUTA'): 5930,
#  ('VILLAVICENCIO', 'CUCUTA'): 7269,
#  ('YOPAL', 'CUCUTA'): 10907,
#  ('ARAUCA', 'FLORENCIA'): 6002,
#  ('BARRANQUILA', 'FLORENCIA'): 7579,
#  ('BOGOTA', 'FLORENCIA'): 12289,
#  ('BUCARAMANGA', 'FLORENCIA'): 7222,
#  ('CALI', 'FLORENCIA'): 9744,
#  ('CUCUTA', 'FLORENCIA'): 5803,
#  ('FLORENCIA', 'FLORENCIA'): 8522,
#  ('IBAGUE', 'FLORENCIA'): 8744,
#  ('MANIZALES', 'FLORENCIA'): 12188,
#  ('MEDELLIN', 'FLORENCIA'): 10977,
#  ('MOCOA', 'FLORENCIA'): 10739,
#  ('MONTERIA', 'FLORENCIA'): 6535,
#  ('NEIVA', 'FLORENCIA'): 8717,
#  ('PASTO', 'FLORENCIA'): 6178,
#  ('POPAYAN', 'FLORENCIA'): 7540,
#  ('PROVIDENCIA', 'FLORENCIA'): 10336,
#  ('SAN ANDRES', 'FLORENCIA'): 8006,
#  ('SINCELEJO', 'FLORENCIA'): 6777,
#  ('TUNJA', 'FLORENCIA'): 9431,
#  ('VALLEDUPAR', 'FLORENCIA'): 7541,
#  ('VILLAVICENCIO', 'FLORENCIA'): 9820,
#  ('YOPAL', 'FLORENCIA'): 11941,
#  ('ARAUCA', 'IBAGUE'): 10893,
#  ('BARRANQUILA', 'IBAGUE'): 5878,
#  ('BOGOTA', 'IBAGUE'): 7029,
#  ('BUCARAMANGA', 'IBAGUE'): 5829,
#  ('CALI', 'IBAGUE'): 11078,
#  ('CUCUTA', 'IBAGUE'): 12184,
#  ('FLORENCIA', 'IBAGUE'): 7087,
#  ('IBAGUE', 'IBAGUE'): 10524,
#  ('MANIZALES', 'IBAGUE'): 11815,
#  ('MEDELLIN', 'IBAGUE'): 5925,
#  ('MOCOA', 'IBAGUE'): 8606,
#  ('MONTERIA', 'IBAGUE'): 10094,
#  ('NEIVA', 'IBAGUE'): 7678,
#  ('PASTO', 'IBAGUE'): 8002,
#  ('POPAYAN', 'IBAGUE'): 10010,
#  ('PROVIDENCIA', 'IBAGUE'): 11070,
#  ('SAN ANDRES', 'IBAGUE'): 6380,
#  ('SINCELEJO', 'IBAGUE'): 9682,
#  ('TUNJA', 'IBAGUE'): 9950,
#  ('VALLEDUPAR', 'IBAGUE'): 8987,
#  ('VILLAVICENCIO', 'IBAGUE'): 11032,
#  ('YOPAL', 'IBAGUE'): 7849,
#  ('ARAUCA', 'MANIZALES'): 8234,
#  ('BARRANQUILA', 'MANIZALES'): 6231,
#  ('BOGOTA', 'MANIZALES'): 11880,
#  ('BUCARAMANGA', 'MANIZALES'): 10347,
#  ('CALI', 'MANIZALES'): 11261,
#  ('CUCUTA', 'MANIZALES'): 7904,
#  ('FLORENCIA', 'MANIZALES'): 8655,
#  ('IBAGUE', 'MANIZALES'): 8607,
#  ('MANIZALES', 'MANIZALES'): 10968,
#  ('MEDELLIN', 'MANIZALES'): 9615,
#  ('MOCOA', 'MANIZALES'): 9806,
#  ('MONTERIA', 'MANIZALES'): 8178,
#  ('NEIVA', 'MANIZALES'): 12117,
#  ('PASTO', 'MANIZALES'): 8949,
#  ('POPAYAN', 'MANIZALES'): 9803,
#  ('PROVIDENCIA', 'MANIZALES'): 10254,
#  ('SAN ANDRES', 'MANIZALES'): 11384,
#  ('SINCELEJO', 'MANIZALES'): 8889,
#  ('TUNJA', 'MANIZALES'): 10012,
#  ('VALLEDUPAR', 'MANIZALES'): 9821,
#  ('VILLAVICENCIO', 'MANIZALES'): 8625,
#  ('YOPAL', 'MANIZALES'): 6843,
#  ('ARAUCA', 'MEDELLIN'): 10022,
#  ('BARRANQUILA', 'MEDELLIN'): 11815,
#  ('BOGOTA', 'MEDELLIN'): 10285,
#  ('BUCARAMANGA', 'MEDELLIN'): 6865,
#  ('CALI', 'MEDELLIN'): 7857,
#  ('CUCUTA', 'MEDELLIN'): 8834,
#  ('FLORENCIA', 'MEDELLIN'): 9868,
#  ('IBAGUE', 'MEDELLIN'): 10912,
#  ('MANIZALES', 'MEDELLIN'): 12270,
#  ('MEDELLIN', 'MEDELLIN'): 9915,
#  ('MOCOA', 'MEDELLIN'): 7111,
#  ('MONTERIA', 'MEDELLIN'): 10239,
#  ('NEIVA', 'MEDELLIN'): 12160,
#  ('PASTO', 'MEDELLIN'): 7352,
#  ('POPAYAN', 'MEDELLIN'): 9890,
#  ('PROVIDENCIA', 'MEDELLIN'): 11402,
#  ('SAN ANDRES', 'MEDELLIN'): 7994,
#  ('SINCELEJO', 'MEDELLIN'): 7908,
#  ('TUNJA', 'MEDELLIN'): 9128,
#  ('VALLEDUPAR', 'MEDELLIN'): 8408,
#  ('VILLAVICENCIO', 'MEDELLIN'): 10644,
#  ('YOPAL', 'MEDELLIN'): 6941,
#  ('ARAUCA', 'MOCOA'): 7141,
#  ('BARRANQUILA', 'MOCOA'): 8312,
#  ('BOGOTA', 'MOCOA'): 12226,
#  ('BUCARAMANGA', 'MOCOA'): 7979,
#  ('CALI', 'MOCOA'): 8829,
#  ('CUCUTA', 'MOCOA'): 6112,
#  ('FLORENCIA', 'MOCOA'): 7107,
#  ('IBAGUE', 'MOCOA'): 7730,
#  ('MANIZALES', 'MOCOA'): 12052,
#  ('MEDELLIN', 'MOCOA'): 7752,
#  ('MOCOA', 'MOCOA'): 11220,
#  ('MONTERIA', 'MOCOA'): 8926,
#  ('NEIVA', 'MOCOA'): 7613,
#  ('PASTO', 'MOCOA'): 8389,
#  ('POPAYAN', 'MOCOA'): 7960,
#  ('PROVIDENCIA', 'MOCOA'): 9054,
#  ('SAN ANDRES', 'MOCOA'): 9836,
#  ('SINCELEJO', 'MOCOA'): 10307,
#  ('TUNJA', 'MOCOA'): 7616,
#  ('VALLEDUPAR', 'MOCOA'): 11548,
#  ('VILLAVICENCIO', 'MOCOA'): 7966,
#  ('YOPAL', 'MOCOA'): 5939,
#  ('ARAUCA', 'MONTERIA'): 12270,
#  ('BARRANQUILA', 'MONTERIA'): 8633,
#  ('BOGOTA', 'MONTERIA'): 9900,
#  ('BUCARAMANGA', 'MONTERIA'): 6578,
#  ('CALI', 'MONTERIA'): 10103,
#  ('CUCUTA', 'MONTERIA'): 11360,
#  ('FLORENCIA', 'MONTERIA'): 8634,
#  ('IBAGUE', 'MONTERIA'): 12039,
#  ('MANIZALES', 'MONTERIA'): 11629,
#  ('MEDELLIN', 'MONTERIA'): 7167,
#  ('MOCOA', 'MONTERIA'): 9434,
#  ('MONTERIA', 'MONTERIA'): 8580,
#  ('NEIVA', 'MONTERIA'): 8252,
#  ('PASTO', 'MONTERIA'): 9548,
#  ('POPAYAN', 'MONTERIA'): 8242,
#  ('PROVIDENCIA', 'MONTERIA'): 7027,
#  ('SAN ANDRES', 'MONTERIA'): 8765,
#  ('SINCELEJO', 'MONTERIA'): 7997,
#  ('TUNJA', 'MONTERIA'): 7039,
#  ('VALLEDUPAR', 'MONTERIA'): 6667,
#  ('VILLAVICENCIO', 'MONTERIA'): 6678,
#  ('YOPAL', 'MONTERIA'): 8910,
#  ('ARAUCA', 'NEIVA'): 6228,
#  ('BARRANQUILA', 'NEIVA'): 10464,
#  ('BOGOTA', 'NEIVA'): 6273,
#  ('BUCARAMANGA', 'NEIVA'): 9567,
#  ('CALI', 'NEIVA'): 9766,
#  ('CUCUTA', 'NEIVA'): 11424,
#  ('FLORENCIA', 'NEIVA'): 7963,
#  ('IBAGUE', 'NEIVA'): 10641,
#  ('MANIZALES', 'NEIVA'): 9675,
#  ('MEDELLIN', 'NEIVA'): 9734,
#  ('MOCOA', 'NEIVA'): 6350,
#  ('MONTERIA', 'NEIVA'): 11423,
#  ('NEIVA', 'NEIVA'): 7240,
#  ('PASTO', 'NEIVA'): 6313,
#  ('POPAYAN', 'NEIVA'): 7992,
#  ('PROVIDENCIA', 'NEIVA'): 10638,
#  ('SAN ANDRES', 'NEIVA'): 9666,
#  ('SINCELEJO', 'NEIVA'): 11163,
#  ('TUNJA', 'NEIVA'): 7814,
#  ('VALLEDUPAR', 'NEIVA'): 6986,
#  ('VILLAVICENCIO', 'NEIVA'): 10647,
#  ('YOPAL', 'NEIVA'): 8555,
#  ('ARAUCA', 'PASTO'): 10467,
#  ('BARRANQUILA', 'PASTO'): 11251,
#  ('BOGOTA', 'PASTO'): 10644,
#  ('BUCARAMANGA', 'PASTO'): 9605,
#  ('CALI', 'PASTO'): 10657,
#  ('CUCUTA', 'PASTO'): 7950,
#  ('FLORENCIA', 'PASTO'): 7942,
#  ('IBAGUE', 'PASTO'): 11148,
#  ('MANIZALES', 'PASTO'): 10510,
#  ('MEDELLIN', 'PASTO'): 11279,
#  ('MOCOA', 'PASTO'): 8823,
#  ('MONTERIA', 'PASTO'): 7386,
#  ('NEIVA', 'PASTO'): 9647,
#  ('PASTO', 'PASTO'): 6535,
#  ('POPAYAN', 'PASTO'): 10508,
#  ('PROVIDENCIA', 'PASTO'): 8244,
#  ('SAN ANDRES', 'PASTO'): 12214,
#  ('SINCELEJO', 'PASTO'): 7029,
#  ('TUNJA', 'PASTO'): 7081,
#  ('VALLEDUPAR', 'PASTO'): 9417,
#  ('VILLAVICENCIO', 'PASTO'): 9064,
#  ('YOPAL', 'PASTO'): 9521,
#  ('ARAUCA', 'POPAYAN'): 7601,
#  ('BARRANQUILA', 'POPAYAN'): 6067,
#  ('BOGOTA', 'POPAYAN'): 10685,
#  ('BUCARAMANGA', 'POPAYAN'): 6737,
#  ('CALI', 'POPAYAN'): 10808,
#  ('CUCUTA', 'POPAYAN'): 11859,
#  ('FLORENCIA', 'POPAYAN'): 9818,
#  ('IBAGUE', 'POPAYAN'): 10987,
#  ('MANIZALES', 'POPAYAN'): 11831,
#  ('MEDELLIN', 'POPAYAN'): 6641,
#  ('MOCOA', 'POPAYAN'): 8907,
#  ('MONTERIA', 'POPAYAN'): 7246,
#  ('NEIVA', 'POPAYAN'): 10777,
#  ('PASTO', 'POPAYAN'): 6308,
#  ('POPAYAN', 'POPAYAN'): 11295,
#  ('PROVIDENCIA', 'POPAYAN'): 7920,
#  ('SAN ANDRES', 'POPAYAN'): 7453,
#  ('SINCELEJO', 'POPAYAN'): 5846,
#  ('TUNJA', 'POPAYAN'): 9793,
#  ('VALLEDUPAR', 'POPAYAN'): 12254,
#  ('VILLAVICENCIO', 'POPAYAN'): 8166,
#  ('YOPAL', 'POPAYAN'): 6975,
#  ('ARAUCA', 'PROVIDENCIA'): 6869,
#  ('BARRANQUILA', 'PROVIDENCIA'): 7764,
#  ('BOGOTA', 'PROVIDENCIA'): 6875,
#  ('BUCARAMANGA', 'PROVIDENCIA'): 8059,
#  ('CALI', 'PROVIDENCIA'): 7994,
#  ('CUCUTA', 'PROVIDENCIA'): 11276,
#  ('FLORENCIA', 'PROVIDENCIA'): 8002,
#  ('IBAGUE', 'PROVIDENCIA'): 7296,
#  ('MANIZALES', 'PROVIDENCIA'): 9280,
#  ('MEDELLIN', 'PROVIDENCIA'): 5926,
#  ('MOCOA', 'PROVIDENCIA'): 7451,
#  ('MONTERIA', 'PROVIDENCIA'): 7893,
#  ('NEIVA', 'PROVIDENCIA'): 9558,
#  ('PASTO', 'PROVIDENCIA'): 11052,
#  ('POPAYAN', 'PROVIDENCIA'): 11802,
#  ('PROVIDENCIA', 'PROVIDENCIA'): 11508,
#  ('SAN ANDRES', 'PROVIDENCIA'): 8508,
#  ('SINCELEJO', 'PROVIDENCIA'): 6312,
#  ('TUNJA', 'PROVIDENCIA'): 5960,
#  ('VALLEDUPAR', 'PROVIDENCIA'): 10919,
#  ('VILLAVICENCIO', 'PROVIDENCIA'): 10482,
#  ('YOPAL', 'PROVIDENCIA'): 7703,
#  ('ARAUCA', 'SAN ANDRES'): 8959,
#  ('BARRANQUILA', 'SAN ANDRES'): 9369,
#  ('BOGOTA', 'SAN ANDRES'): 8552,
#  ('BUCARAMANGA', 'SAN ANDRES'): 7227,
#  ('CALI', 'SAN ANDRES'): 8763,
#  ('CUCUTA', 'SAN ANDRES'): 11774,
#  ('FLORENCIA', 'SAN ANDRES'): 11831,
#  ('IBAGUE', 'SAN ANDRES'): 7854,
#  ('MANIZALES', 'SAN ANDRES'): 9351,
#  ('MEDELLIN', 'SAN ANDRES'): 7478,
#  ('MOCOA', 'SAN ANDRES'): 9312,
#  ('MONTERIA', 'SAN ANDRES'): 12264,
#  ('NEIVA', 'SAN ANDRES'): 7976,
#  ('PASTO', 'SAN ANDRES'): 11324,
#  ('POPAYAN', 'SAN ANDRES'): 8922,
#  ('PROVIDENCIA', 'SAN ANDRES'): 8482,
#  ('SAN ANDRES', 'SAN ANDRES'): 10633,
#  ('SINCELEJO', 'SAN ANDRES'): 10346,
#  ('TUNJA', 'SAN ANDRES'): 9670,
#  ('VALLEDUPAR', 'SAN ANDRES'): 7063,
#  ('VILLAVICENCIO', 'SAN ANDRES'): 10942,
#  ('YOPAL', 'SAN ANDRES'): 11698,
#  ('ARAUCA', 'SINCELEJO'): 6542,
#  ('BARRANQUILA', 'SINCELEJO'): 6344,
#  ('BOGOTA', 'SINCELEJO'): 10056,
#  ('BUCARAMANGA', 'SINCELEJO'): 6087,
#  ('CALI', 'SINCELEJO'): 10521,
#  ('CUCUTA', 'SINCELEJO'): 10194,
#  ('FLORENCIA', 'SINCELEJO'): 10442,
#  ('IBAGUE', 'SINCELEJO'): 8352,
#  ('MANIZALES', 'SINCELEJO'): 11192,
#  ('MEDELLIN', 'SINCELEJO'): 6161,
#  ('MOCOA', 'SINCELEJO'): 6142,
#  ('MONTERIA', 'SINCELEJO'): 5906,
#  ('NEIVA', 'SINCELEJO'): 8190,
#  ('PASTO', 'SINCELEJO'): 7936,
#  ('POPAYAN', 'SINCELEJO'): 9396,
#  ('PROVIDENCIA', 'SINCELEJO'): 9638,
#  ('SAN ANDRES', 'SINCELEJO'): 7359,
#  ('SINCELEJO', 'SINCELEJO'): 12281,
#  ('TUNJA', 'SINCELEJO'): 11605,
#  ('VALLEDUPAR', 'SINCELEJO'): 10359,
#  ('VILLAVICENCIO', 'SINCELEJO'): 6351,
#  ('YOPAL', 'SINCELEJO'): 6621,
#  ('ARAUCA', 'TUNJA'): 9033,
#  ('BARRANQUILA', 'TUNJA'): 10194,
#  ('BOGOTA', 'TUNJA'): 5932,
#  ('BUCARAMANGA', 'TUNJA'): 10714,
#  ('CALI', 'TUNJA'): 9008,
#  ('CUCUTA', 'TUNJA'): 11289,
#  ('FLORENCIA', 'TUNJA'): 8858,
#  ('IBAGUE', 'TUNJA'): 6637,
#  ('MANIZALES', 'TUNJA'): 11956,
#  ('MEDELLIN', 'TUNJA'): 11167,
#  ('MOCOA', 'TUNJA'): 10062,
#  ('MONTERIA', 'TUNJA'): 6508,
#  ('NEIVA', 'TUNJA'): 8702,
#  ('PASTO', 'TUNJA'): 8307,
#  ('POPAYAN', 'TUNJA'): 9709,
#  ('PROVIDENCIA', 'TUNJA'): 9622,
#  ('SAN ANDRES', 'TUNJA'): 6115,
#  ('SINCELEJO', 'TUNJA'): 8697,
#  ('TUNJA', 'TUNJA'): 7065,
#  ('VALLEDUPAR', 'TUNJA'): 8955,
#  ('VILLAVICENCIO', 'TUNJA'): 8467,
#  ('YOPAL', 'TUNJA'): 7850,
#  ('ARAUCA', 'VALLEDUPAR'): 7160,
#  ('BARRANQUILA', 'VALLEDUPAR'): 6118,
#  ('BOGOTA', 'VALLEDUPAR'): 8530,
#  ('BUCARAMANGA', 'VALLEDUPAR'): 7231,
#  ('CALI', 'VALLEDUPAR'): 8920,
#  ('CUCUTA', 'VALLEDUPAR'): 10343,
#  ('FLORENCIA', 'VALLEDUPAR'): 10211,
#  ('IBAGUE', 'VALLEDUPAR'): 7352,
#  ('MANIZALES', 'VALLEDUPAR'): 7283,
#  ('MEDELLIN', 'VALLEDUPAR'): 7208,
#  ('MOCOA', 'VALLEDUPAR'): 8991,
#  ('MONTERIA', 'VALLEDUPAR'): 9702,
#  ('NEIVA', 'VALLEDUPAR'): 8462,
#  ('PASTO', 'VALLEDUPAR'): 10329,
#  ('POPAYAN', 'VALLEDUPAR'): 11529,
#  ('PROVIDENCIA', 'VALLEDUPAR'): 7540,
#  ('SAN ANDRES', 'VALLEDUPAR'): 7377,
#  ('SINCELEJO', 'VALLEDUPAR'): 6357,
#  ('TUNJA', 'VALLEDUPAR'): 10396,
#  ('VALLEDUPAR', 'VALLEDUPAR'): 6019,
#  ('VILLAVICENCIO', 'VALLEDUPAR'): 9222,
#  ('YOPAL', 'VALLEDUPAR'): 7602,
#  ('ARAUCA', 'VILLAVICENCIO'): 8833,
#  ('BARRANQUILA', 'VILLAVICENCIO'): 12090,
#  ('BOGOTA', 'VILLAVICENCIO'): 9399,
#  ('BUCARAMANGA', 'VILLAVICENCIO'): 11568,
#  ('CALI', 'VILLAVICENCIO'): 7286,
#  ('CUCUTA', 'VILLAVICENCIO'): 7194,
#  ('FLORENCIA', 'VILLAVICENCIO'): 7067,
#  ('IBAGUE', 'VILLAVICENCIO'): 9560,
#  ('MANIZALES', 'VILLAVICENCIO'): 6042,
#  ('MEDELLIN', 'VILLAVICENCIO'): 6664,
#  ('MOCOA', 'VILLAVICENCIO'): 5922,
#  ('MONTERIA', 'VILLAVICENCIO'): 11164,
#  ('NEIVA', 'VILLAVICENCIO'): 11209,
#  ('PASTO', 'VILLAVICENCIO'): 11727,
#  ('POPAYAN', 'VILLAVICENCIO'): 7388,
#  ('PROVIDENCIA', 'VILLAVICENCIO'): 10720,
#  ('SAN ANDRES', 'VILLAVICENCIO'): 12169,
#  ('SINCELEJO', 'VILLAVICENCIO'): 9159,
#  ('TUNJA', 'VILLAVICENCIO'): 10814,
#  ('VALLEDUPAR', 'VILLAVICENCIO'): 7697,
#  ('VILLAVICENCIO', 'VILLAVICENCIO'): 11413,
#  ('YOPAL', 'VILLAVICENCIO'): 7719,
#  ('ARAUCA', 'YOPAL'): 8792,
#  ('BARRANQUILA', 'YOPAL'): 10235,
#  ('BOGOTA', 'YOPAL'): 9096,
#  ('BUCARAMANGA', 'YOPAL'): 6057,
#  ('CALI', 'YOPAL'): 9850,
#  ('CUCUTA', 'YOPAL'): 5836,
#  ('FLORENCIA', 'YOPAL'): 11836,
#  ('IBAGUE', 'YOPAL'): 11979,
#  ('MANIZALES', 'YOPAL'): 9643,
#  ('MEDELLIN', 'YOPAL'): 10597,
#  ('MOCOA', 'YOPAL'): 10942,
#  ('MONTERIA', 'YOPAL'): 10030,
#  ('NEIVA', 'YOPAL'): 12105,
#  ('PASTO', 'YOPAL'): 7535,
#  ('POPAYAN', 'YOPAL'): 10046,
#  ('PROVIDENCIA', 'YOPAL'): 8025,
#  ('SAN ANDRES', 'YOPAL'): 7514,
#  ('SINCELEJO', 'YOPAL'): 6378,
#  ('TUNJA', 'YOPAL'): 7958,
#  ('VALLEDUPAR', 'YOPAL'): 6723,
#  ('VILLAVICENCIO', 'YOPAL'): 11061,
#  ('YOPAL', 'YOPAL'): 8467}

# %% [markdown]
# ## Modelamiento
# ---

# %%
#Definición del problema
problema = lp.LpProblem('Minimización_Costos', lp.LpMinimize)

# %%
# Variable X_kj
x = lp.LpVariable.dicts(
    name = 'ruta',
    indices = CARxCLC,
    lowBound=0,
    cat=lp.LpInteger
)

# %%
# Variable m_kj
#m = lp.LpVariable.dicts(
 #   name = 'ruta',
  #  indices = CARxCLC,
   # lowBound=0,
    #cat=lp.LpInteger
#)

# %%
# Variable Y_ij
y = lp.LpVariable.dicts(
    name = 'ruta',
    indices = Oficina_x_CLC,
    lowBound=0,
    cat=lp.LpInteger
)

# %% [markdown]
# ### Función Objetivo

# %%
#problema += lp.lpSum(costos_w[k,j]*x[k,j] for k in lista_car for j in lista_clc) + lp.lpSum(costos_w_extra[k,j]*m[k,j] for k in lista_car for j in lista_clc)+ lp.lpSum(costo_transporte_oficinas[i,j]*y[i,j] for i in lista_oficinas for j in lista_clc), 'Costos minimos'
problema += lp.lpSum(costos_w[k,j]*x[k,j] for k in lista_car for j in lista_clc) + lp.lpSum(costo_transporte_oficinas[i,j]*y[i,j] for i in lista_oficinas for j in lista_clc), 'Costos minimos'

# %% [markdown]
# ### Restricciones

# %%
#Demanda Oficina
for i in lista_oficinas:
    problema += lp.lpSum(y[i,j] for j in lista_clc) >= demanda_oficina[i]

# %%
#Demanda CAR
for k in lista_car:
    problema += lp.lpSum(x[k,j] for j in lista_clc) >= demanda_car[k]

# %%
#No superar peso máximo ~ Restricción suave
for j in lista_clc:
    problema += lp.lpSum(peso_tula[k]*x[k,j] for k in lista_car) >= 30

# %% [markdown]
# ### Invocar el optimizador

# %%
problema.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/santiagoromero/anaconda3/envs/Maestria/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/cw/dvczbrmn4d7g1pplvzvyvc2h0000gn/T/f8a41cd753d0414f8d3f4c2f411bfa24-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/cw/dvczbrmn4d7g1pplvzvyvc2h0000gn/T/f8a41cd753d0414f8d3f4c2f411bfa24-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 839 COLUMNS
# Duplicate row C0000040 at line 4455 <     X0000903  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4456 <     X0000903  C0000790   1.000000000000e+00 >
# Duplicate row C0000812 at line 4457 <     X0000903  C0000812   5.000000000000e+00 >
# Duplicate objective at line 4458 <     X0000903  OBJ        1.061300000000e+04 >
# Duplicate row C0000040 at line 4467 <     X0000905  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4468 <     X0000905  C0000790   1.000000000000e+00 >
# Duplicate row C0000813 at line 4469 <     X0000905  C0000813   5.000000000000e+00 >
# Duplicate objective at line 4470 <     X0000905  OBJ        6.731000000000e+03 >
# Duplicate row C0000040 at line 4479 <     X0000907  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4480 <     X0000907  C0000790   1.000000000000e+00 >
# Duplicate row C0000814 at line 4481 <     X0000907  C0000814   5.000000000000e+00 >
# Duplicate objective at line 4482 <     X0000907  OBJ        5.785000000000e+03 >
# Duplicate row C0000040 at line 4491 <     X0000909  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4492 <     X0000909  C0000790   1.000000000000e+00 >
# Duplicate row C0000815 at line 4493 <     X0000909  C0000815   5.000000000000e+00 >
# Duplicate objective at line 4494 <     X0000909  OBJ        7.681000000000e+03 >
# Duplicate row C0000040 at line 4503 <     X0000911  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4504 <     X0000911  C0000790   1.000000000000e+00 >
# Duplicate row C0000816 at line 4505 <     X0000911  C0000816   5.000000000000e+00 >
# Duplicate objective at line 4506 <     X0000911  OBJ        6.014000000000e+03 >
# Duplicate row C0000040 at line 4515 <     X0000913  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4516 <     X0000913  C0000790   1.000000000000e+00 >
# Duplicate row C0000817 at line 4517 <     X0000913  C0000817   5.000000000000e+00 >
# Duplicate objective at line 4518 <     X0000913  OBJ        6.025000000000e+03 >
# Duplicate row C0000040 at line 4527 <     X0000915  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4528 <     X0000915  C0000790   1.000000000000e+00 >
# Duplicate row C0000818 at line 4529 <     X0000915  C0000818   5.000000000000e+00 >
# Duplicate objective at line 4530 <     X0000915  OBJ        6.002000000000e+03 >
# Duplicate row C0000040 at line 4539 <     X0000917  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4540 <     X0000917  C0000790   1.000000000000e+00 >
# Duplicate row C0000819 at line 4541 <     X0000917  C0000819   5.000000000000e+00 >
# Duplicate objective at line 4542 <     X0000917  OBJ        1.089300000000e+04 >
# Duplicate row C0000040 at line 4551 <     X0000919  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4552 <     X0000919  C0000790   1.000000000000e+00 >
# Duplicate row C0000820 at line 4553 <     X0000919  C0000820   5.000000000000e+00 >
# Duplicate objective at line 4554 <     X0000919  OBJ        8.234000000000e+03 >
# Duplicate row C0000040 at line 4563 <     X0000921  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4564 <     X0000921  C0000790   1.000000000000e+00 >
# Duplicate row C0000821 at line 4565 <     X0000921  C0000821   5.000000000000e+00 >
# Duplicate objective at line 4566 <     X0000921  OBJ        1.002200000000e+04 >
# Duplicate row C0000040 at line 4575 <     X0000923  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4576 <     X0000923  C0000790   1.000000000000e+00 >
# Duplicate row C0000822 at line 4577 <     X0000923  C0000822   5.000000000000e+00 >
# Duplicate objective at line 4578 <     X0000923  OBJ        7.141000000000e+03 >
# Duplicate row C0000040 at line 4587 <     X0000925  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4588 <     X0000925  C0000790   1.000000000000e+00 >
# Duplicate row C0000823 at line 4589 <     X0000925  C0000823   5.000000000000e+00 >
# Duplicate objective at line 4590 <     X0000925  OBJ        1.227000000000e+04 >
# Duplicate row C0000040 at line 4599 <     X0000927  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4600 <     X0000927  C0000790   1.000000000000e+00 >
# Duplicate row C0000824 at line 4601 <     X0000927  C0000824   5.000000000000e+00 >
# Duplicate objective at line 4602 <     X0000927  OBJ        6.228000000000e+03 >
# Duplicate row C0000040 at line 4611 <     X0000929  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4612 <     X0000929  C0000790   1.000000000000e+00 >
# Duplicate row C0000825 at line 4613 <     X0000929  C0000825   5.000000000000e+00 >
# Duplicate objective at line 4614 <     X0000929  OBJ        1.046700000000e+04 >
# Duplicate row C0000040 at line 4623 <     X0000931  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4624 <     X0000931  C0000790   1.000000000000e+00 >
# Duplicate row C0000826 at line 4625 <     X0000931  C0000826   5.000000000000e+00 >
# Duplicate objective at line 4626 <     X0000931  OBJ        7.601000000000e+03 >
# Duplicate row C0000040 at line 4635 <     X0000933  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4636 <     X0000933  C0000790   1.000000000000e+00 >
# Duplicate row C0000827 at line 4637 <     X0000933  C0000827   5.000000000000e+00 >
# Duplicate objective at line 4638 <     X0000933  OBJ        6.869000000000e+03 >
# Duplicate row C0000040 at line 4647 <     X0000935  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4648 <     X0000935  C0000790   1.000000000000e+00 >
# Duplicate row C0000828 at line 4649 <     X0000935  C0000828   5.000000000000e+00 >
# Duplicate objective at line 4650 <     X0000935  OBJ        8.959000000000e+03 >
# Duplicate row C0000040 at line 4659 <     X0000937  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4660 <     X0000937  C0000790   1.000000000000e+00 >
# Duplicate row C0000829 at line 4661 <     X0000937  C0000829   5.000000000000e+00 >
# Duplicate objective at line 4662 <     X0000937  OBJ        6.542000000000e+03 >
# Duplicate row C0000040 at line 4671 <     X0000939  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4672 <     X0000939  C0000790   1.000000000000e+00 >
# Duplicate row C0000830 at line 4673 <     X0000939  C0000830   5.000000000000e+00 >
# Duplicate objective at line 4674 <     X0000939  OBJ        9.033000000000e+03 >
# Duplicate row C0000040 at line 4683 <     X0000941  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4684 <     X0000941  C0000790   1.000000000000e+00 >
# Duplicate row C0000831 at line 4685 <     X0000941  C0000831   5.000000000000e+00 >
# Duplicate objective at line 4686 <     X0000941  OBJ        7.160000000000e+03 >
# Duplicate row C0000040 at line 4695 <     X0000943  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4696 <     X0000943  C0000790   1.000000000000e+00 >
# Duplicate row C0000832 at line 4697 <     X0000943  C0000832   5.000000000000e+00 >
# Duplicate objective at line 4698 <     X0000943  OBJ        8.833000000000e+03 >
# Duplicate row C0000040 at line 4707 <     X0000945  C0000040   1.000000000000e+00 >
# Duplicate row C0000790 at line 4708 <     X0000945  C0000790   1.000000000000e+00 >
# Duplicate row C0000833 at line 4709 <     X0000945  C0000833   5.000000000000e+00 >
# Duplicate objective at line 4710 <     X0000945  OBJ        8.792000000000e+03 >
# Duplicate row C0000099 at line 9581 <     X0002113  C0000099   1.000000000000e+00 >
# Duplicate row C0000793 at line 9582 <     X0002113  C0000793   1.000000000000e+00 >
# Duplicate row C0000812 at line 9583 <     X0002113  C0000812   5.000000000000e+00 >
# Duplicate objective at line 9584 <     X0002113  OBJ        7.308000000000e+03 >
# Duplicate row C0000099 at line 9593 <     X0002115  C0000099   1.000000000000e+00 >
# Duplicate row C0000793 at line 9594 <     X0002115  C0000793   1.000000000000e+00 >
# Duplicate row C0000813 at line 9595 <     X0002115  C0000813   5.000000000000e+00 >
# Duplicate objective at line 9596 <     X0002115  OBJ        6.730000000000e+03 >
# Duplicate row C0000099 at line 9605 <     X0002117  C0000099   1.000000000000e+00 >
# Duplicate row C0000793 at line 9606 <     X0002117  C0000793   1.000000000000e+00 >
# Duplicate row C0000814 at line 9607 <     X0002117  C0000814   5.000000000000e+00 >
# At line 71284 RHS
# At line 72119 BOUNDS
# At line 89082 ENDATA
# Problem MODEL has 834 rows, 16566 columns and 18348 elements
# Coin0008I MODEL read with 2002 errors
# There were 2002 errors on input
# Option for timeMode changed from cpu to elapsed
# ** Current model not valid
# Option for printingOptions changed from normal to all
# ** Current model not valid
# No match for /var/folders/cw/dvczbrmn4d7g1pplvzvyvc2h0000gn/T/f8a41cd753d0414f8d3f4c2f411bfa24-pulp.sol - ? for list of commands
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
# ---------------------------------------------------------------------------
# PulpSolverError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 problema.solve()
#
# File ~/anaconda3/envs/Maestria/lib/python3.11/site-packages/pulp/pulp.py:1913, in LpProblem.solve(self, solver, **kwargs)
#    1911 # time it
#    1912 self.startClock()
# -> 1913 status = solver.actualSolve(self, **kwargs)
#    1914 self.stopClock()
#    1915 self.restoreObjective(wasNone, dummyVar)
#
# File ~/anaconda3/envs/Maestria/lib/python3.11/site-packages/pulp/apis/coin_api.py:137, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     135 def actualSolve(self, lp, **kwargs):
#     136     """Solve a well formulated lp problem"""
# --> 137     return self.solve_CBC(lp, **kwargs)
#
# File ~/anaconda3/envs/Maestria/lib/python3.11/site-packages/pulp/apis/coin_api.py:213, in COIN_CMD.solve_CBC(self, lp, use_mps)
#     211     pipe.close()
#     212 if not os.path.exists(tmpSol):
# --> 213     raise PulpSolverError("Pulp: Error while executing " + self.path)
#     214 (
#     215     status,
#     216     values,
#    (...)
#     220     sol_status,
#     221 ) = self.readsol_MPS(tmpSol, lp, vs, variablesNames, constraintsNames)
#     222 lp.assignVarsVals(values)
#
# PulpSolverError: Pulp: Error while executing /Users/santiagoromero/anaconda3/envs/Maestria/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc
