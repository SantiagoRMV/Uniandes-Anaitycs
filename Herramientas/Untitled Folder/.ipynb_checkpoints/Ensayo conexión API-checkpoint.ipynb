# %%
import pandas as pd
import requests

# %%
api_url = "https://www.datos.gov.co/resource/rnvb-vnyh.json?$query=SELECT%0A%20%20%60estu_tipodocumento%60%2C%0A%20%20%60estu_nacionalidad%60%2C%0A%20%20%60estu_genero%60%2C%0A%20%20%60estu_fechanacimiento%60%2C%0A%20%20%60periodo%60%2C%0A%20%20%60estu_consecutivo%60%2C%0A%20%20%60estu_estudiante%60%2C%0A%20%20%60estu_pais_reside%60%2C%0A%20%20%60estu_tieneetnia%60%2C%0A%20%20%60estu_depto_reside%60%2C%0A%20%20%60estu_cod_reside_depto%60%2C%0A%20%20%60estu_mcpio_reside%60%2C%0A%20%20%60estu_cod_reside_mcpio%60%2C%0A%20%20%60fami_estratovivienda%60%2C%0A%20%20%60fami_personashogar%60%2C%0A%20%20%60fami_cuartoshogar%60%2C%0A%20%20%60fami_educacionpadre%60%2C%0A%20%20%60fami_educacionmadre%60%2C%0A%20%20%60fami_trabajolaborpadre%60%2C%0A%20%20%60fami_trabajolabormadre%60%2C%0A%20%20%60fami_tieneinternet%60%2C%0A%20%20%60fami_tieneserviciotv%60%2C%0A%20%20%60fami_tienecomputador%60%2C%0A%20%20%60fami_tienelavadora%60%2C%0A%20%20%60fami_tienehornomicroogas%60%2C%0A%20%20%60fami_tieneautomovil%60%2C%0A%20%20%60fami_tienemotocicleta%60%2C%0A%20%20%60fami_tieneconsolavideojuegos%60%2C%0A%20%20%60fami_numlibros%60%2C%0A%20%20%60fami_comelechederivados%60%2C%0A%20%20%60fami_comecarnepescadohuevo%60%2C%0A%20%20%60fami_comecerealfrutoslegumbre%60%2C%0A%20%20%60fami_situacioneconomica%60%2C%0A%20%20%60estu_dedicacionlecturadiaria%60%2C%0A%20%20%60estu_dedicacioninternet%60%2C%0A%20%20%60estu_horassemanatrabaja%60%2C%0A%20%20%60estu_tiporemuneracion%60%2C%0A%20%20%60cole_codigo_icfes%60%2C%0A%20%20%60cole_cod_dane_establecimiento%60%2C%0A%20%20%60cole_nombre_establecimiento%60%2C%0A%20%20%60cole_genero%60%2C%0A%20%20%60cole_naturaleza%60%2C%0A%20%20%60cole_calendario%60%2C%0A%20%20%60cole_bilingue%60%2C%0A%20%20%60cole_caracter%60%2C%0A%20%20%60cole_cod_dane_sede%60%2C%0A%20%20%60cole_nombre_sede%60%2C%0A%20%20%60cole_sede_principal%60%2C%0A%20%20%60cole_area_ubicacion%60%2C%0A%20%20%60cole_jornada%60%2C%0A%20%20%60cole_cod_mcpio_ubicacion%60%2C%0A%20%20%60cole_mcpio_ubicacion%60%2C%0A%20%20%60cole_cod_depto_ubicacion%60%2C%0A%20%20%60cole_depto_ubicacion%60%2C%0A%20%20%60estu_privado_libertad%60%2C%0A%20%20%60estu_cod_mcpio_presentacion%60%2C%0A%20%20%60estu_mcpio_presentacion%60%2C%0A%20%20%60estu_depto_presentacion%60%2C%0A%20%20%60estu_cod_depto_presentacion%60%2C%0A%20%20%60punt_lectura_critica%60%2C%0A%20%20%60percentil_lectura_critica%60%2C%0A%20%20%60desemp_lectura_critica%60%2C%0A%20%20%60punt_matematicas%60%2C%0A%20%20%60percentil_matematicas%60%2C%0A%20%20%60desemp_matematicas%60%2C%0A%20%20%60punt_c_naturales%60%2C%0A%20%20%60percentil_c_naturales%60%2C%0A%20%20%60desemp_c_naturales%60%2C%0A%20%20%60punt_sociales_ciudadanas%60%2C%0A%20%20%60percentil_sociales_ciudadanas%60%2C%0A%20%20%60desemp_sociales_ciudadanas%60%2C%0A%20%20%60punt_ingles%60%2C%0A%20%20%60percentil_ingles%60%2C%0A%20%20%60desemp_ingles%60%2C%0A%20%20%60punt_global%60%2C%0A%20%20%60percentil_global%60%2C%0A%20%20%60estu_inse_individual%60%2C%0A%20%20%60estu_nse_individual%60%2C%0A%20%20%60estu_nse_establecimiento%60%2C%0A%20%20%60estu_estadoinvestigacion%60%2C%0A%20%20%60estu_generacion_e%60"  # Reemplaza esto con la URL de la API que deseas usar
response = requests.get(api_url)

if response.status_code == 200:
    data = response.json()  # Si la API responde con datos JSON
else:
    print("Error al obtener datos de la API")

# %%
df = pd.DataFrame(data)
df
# Out:
#     estu_tipodocumento estu_nacionalidad estu_genero     estu_fechanacimiento  \
# 0                   TI             SUIZA           F  2003-03-03T00:00:00.000
# 1                  PEP         VENEZUELA           M  2002-05-10T00:00:00.000
# 2                   TI         VENEZUELA           F  2003-12-14T00:00:00.000
# 3                   CE         VENEZUELA           M  2003-04-12T00:00:00.000
# 4                   TI          COLOMBIA           F  2004-03-03T00:00:00.000
# ..                 ...               ...         ...                      ...
# 995                NES         VENEZUELA           M  2002-04-04T00:00:00.000
# 996                NES         VENEZUELA           M  2003-04-27T00:00:00.000
# 997                NES         VENEZUELA           F  2003-04-21T00:00:00.000
# 998                PEP         VENEZUELA           M  2003-05-30T00:00:00.000
# 999                NES         VENEZUELA           M  2003-09-19T00:00:00.000
#
# ...
