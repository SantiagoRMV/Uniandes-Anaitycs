# %% [markdown]
# # Realizar 4 Insigths del dataset

# %%
import numpy as np
import pandas as pd
csv = "/Users/santiagoromero/Documents/Maestria/Modelos Analisis Estadisticos/adult-census.csv"
data_frame = pd.read_csv(csv)
data_frame.head()
# Out:
#    age   workclass      education  education-num       marital-status  \
# 0   25     Private           11th              7        Never-married
# 1   38     Private        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private   Some-college             10   Married-civ-spouse
# 4   18           ?   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country   class
# 0             0              40   United-States   <=50K
# ...

# %%
data_frame.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %%
data_frame.index
# Out:
# RangeIndex(start=0, stop=48842, step=1)

# %%
data_numerica = data_frame.select_dtypes(include=['int', 'float'])
data_categorica = data_frame.select_dtypes(include=['object'])
df_numerica = data_frame[data_numerica.columns]
df_categorica = data_frame[data_categorica.columns]

# %%
df_numerica
# Out:
#        age  education-num  capital-gain  capital-loss  hours-per-week
# 0       25              7             0             0              40
# 1       38              9             0             0              50
# 2       28             12             0             0              40
# 3       44             10          7688             0              40
# 4       18             10             0             0              30
# ...    ...            ...           ...           ...             ...
# 48837   27             12             0             0              38
# 48838   40              9             0             0              40
# 48839   58              9             0             0              40
# 48840   22              9             0             0              20
# 48841   52              9         15024             0              40
#
# [48842 rows x 5 columns]

# %%
df_categorica
# Out:
#            workclass      education       marital-status          occupation  \
# 0            Private           11th        Never-married   Machine-op-inspct
# 1            Private        HS-grad   Married-civ-spouse     Farming-fishing
# 2          Local-gov     Assoc-acdm   Married-civ-spouse     Protective-serv
# 3            Private   Some-college   Married-civ-spouse   Machine-op-inspct
# 4                  ?   Some-college        Never-married                   ?
# ...              ...            ...                  ...                 ...
# 48837        Private     Assoc-acdm   Married-civ-spouse        Tech-support
# 48838        Private        HS-grad   Married-civ-spouse   Machine-op-inspct
# 48839        Private        HS-grad              Widowed        Adm-clerical
# 48840        Private        HS-grad        Never-married        Adm-clerical
# 48841   Self-emp-inc        HS-grad   Married-civ-spouse     Exec-managerial
#
# ...

# %%
df_1 = data_frame[['workclass','class']]
df_1.head()
# Out:
#     workclass   class
# 0     Private   <=50K
# 1     Private   <=50K
# 2   Local-gov    >50K
# 3     Private    >50K
# 4           ?   <=50K

# %%
import matplotlib.pyplot as plt
plt.plot(data_frame_3)
